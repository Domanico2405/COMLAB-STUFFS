# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
mysubs = ["English", "Math", "Filipino"]
Mdict = {"English": 0, "Math": 1, "Filipino":2}

# %%
GradePeriod = ["1stGrading", "2ndGrading", "3rdGrading"]
Gdict = {"1stGrading":0, "2ndGrading":1, "3rdGrading":2}

# %%
#Final Grades
English_G= [85,98,96]
Math_G=[89,92,95]
Filipino_G=[91,95,88]

FinalGrades = np.array([English_G, Math_G, Filipino_G])

# %%
#Real Grades
English_RG= [75,78,76]
Math_RG=[79,82,85]
Filipino_RG=[81,75,78]

RealGrades = np.array([English_RG, Math_RG, Filipino_RG])

# %%
FinalGrades[Mdict["Filipino"]][Gdict["2ndGrading"]]
# Out:
# np.int64(95)

# %%
FinalGrades[2][1]
# Out:
# np.int64(95)

# %%
My1stGrading = []

for every_grade in mysubs:
    My1stGrading.append(FinalGrades[Mdict[every_grade]][Gdict["1stGrading"]])

My1stGrading
# Out:
# [np.int64(85), np.int64(89), np.int64(91)]
