# %%
subjects=["English", "Math", "Filipino", "Mapeh", "Science"]
print(subjects)
# Out:
# ['English', 'Math', 'Filipino', 'Mapeh', 'Science']

# %%
subjects.append("ESP")
print(subjects)
# Out:
# ['English', 'Math', 'Filipino', 'Mapeh', 'Science', 'ESP']

# %%
subjects.remove("ESP")
print(subjects)

# %%
selected_subs=subjects[0:4:2]
print(selected_subs)
# Out:
# ['English', 'Filipino']
