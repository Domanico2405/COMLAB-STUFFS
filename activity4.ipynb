# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Politician
politician = ["BBM", "ZaldyCo", "SarahDuterte", "AliceGuo", "BongRevilla"]
pdict = {"BBM":0, "ZaldyCo": 1, "SarahDuterte":2, "AliceGuo":3, "BongRevilla":4}

# %%
year = ["2021", "2022", "2023", "2024", "2025"]
ydict = {"2021":0, "2022":1, "2023":2, "2024":3, "2025":4}

# %%
# Salary
BBM_S = [10000, 21000, 35000, 42000, 51000]
ZaldyCo_S = [11000, 20000, 32000, 31000, 50500]
SarahDuterte_S = [10500, 22000, 30000, 41000, 52000]
AliceGuo_S = [9500, 23000, 31000, 40000, 51500]
BongRevilla_S = [10500, 20500, 30500, 40500, 50500]

salary = np.array([BBM_S,ZaldyCo_S, SarahDuterte_S, AliceGuo_S, BongRevilla_S])

# %%
# Porkbarrel
BBM_S = [10000, 20000, 30000, 40000, 50000]
ZaldyCo_S = [10000, 20000, 30000, 40000, 50000]
SarahDuterte_S = [10000, 20000, 30000, 40000, 50000]
AliceGuo_S = [10000, 20000, 30000, 40000, 50000]
BongRevilla_S = [10000, 20000, 30000, 40000, 50000]

porkbarrel = np.array([BBM_S,ZaldyCo_S, SarahDuterte_S, AliceGuo_S, BongRevilla_S])

# %%
Salary2022 = []

for every_politician in politician:
    Salary2022.append(salary[pdict[every_politician]][ydict["2022"]])

Salary2022
# Out:
# [np.int64(21000),
#  np.int64(20000),
#  np.int64(22000),
#  np.int64(23000),
#  np.int64(20500)]

# %%
plt.plot(salary[pdict["BBM"]], ls = "solid", marker ="8",label = politician[0])
plt.plot(salary[pdict["ZaldyCo"]], ls = "solid", marker ="8",label = politician[1])
plt.plot(salary[pdict["AliceGuo"]], ls = "solid", marker ="8",label = politician[2])
plt.plot(salary[pdict["SarahDuterte"]], ls = "solid", marker ="8",label = politician[3])
plt.plot(salary[pdict["BongRevilla"]], ls = "solid", marker ="8",label = politician[4])

plt.gcf().set_size_inches(5,3)
plt.xticks(list(range(0,5)), year)
plt.legend()

# %% [markdown]
# #INSIGHTS
#
# Based on the visualization, We can see that BBM had a major increase in his salary through the years. While Zaldy Co has a great start, but in year 2024 his salary was degraded.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
mydata = pd.read_csv("C:\\FILES BACKUP\\PELEC_PROJECT\\COMLAB-STUFFS\\csv\\student_performance_analysis.csv")

# %%
mydata
# Out:
#     student_id  gender  hours_studied  attendance_percent  \
# 0            1  Female            6.3                  61
# 1            2    Male            7.6                  62
# 2            3  Female            8.9                  63
# 3            4    Male           10.2                  64
# 4            5  Female           11.5                  65
# 5            6    Male           12.8                  66
# 6            7  Female           14.1                  67
# 7            8    Male           15.4                  68
# 8            9  Female           16.7                  69
# 9           10    Male            5.0                  70
# 10          11  Female            6.3                  71
# 11          12    Male            7.6                  72
# 12          13  Female            8.9                  73
# 13          14    Male           10.2                  74
# 14          15  Female           11.5                  75
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             50 non-null     int64
#  1   gender                 50 non-null     object
#  2   hours_studied          50 non-null     float64
#  3   attendance_percent     50 non-null     int64
#  4   assignments_completed  50 non-null     int64
#  5   test_score             50 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 2.5+ KB

# %%
mydata.columns
# Out:
# Index(['student_id', 'gender', 'hours_studied', 'attendance_percent',
#        'assignments_completed', 'test_score'],
#       dtype='object')

# %%
mydata.columns = ['studentId', 'gender', 'hoursStudied', 'attendance_percent',
       'assignmentsCompleted', 'testScore']

# %%
mydata.columns
# Out:
# Index(['studentId', 'gender', 'hoursStudied', 'attendance_percent',
#        'assignmentsCompleted', 'testScore'],
#       dtype='object')

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   studentId             50 non-null     int64
#  1   gender                50 non-null     object
#  2   hoursStudied          50 non-null     float64
#  3   attendance_percent    50 non-null     int64
#  4   assignmentsCompleted  50 non-null     int64
#  5   testScore             50 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 2.5+ KB

# %%
students_assignments_completed = mydata.groupby('testScore')['assignmentsCompleted'].max().reset_index()
sns.lineplot(data=students_assignments_completed, x='assignmentsCompleted', y='testScore', color='green', ls="solid", marker='o')
plt.title("Student's Score in Completing Assignments")
plt.xlabel('assignmentsCompleted')
plt.ylabel('testScore')
plt.gcf().set_size_inches(10, 4)
plt.show()
